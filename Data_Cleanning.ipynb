# %%
import pandas as pd
import numpy as np

# %%
nypd_complains_df = pd.read_csv('cleaned_data/nypd_complaints.csv')
nypd_complains_df
# Out:
#      Unnamed: 0 vic_sex                       offense        date susp_sex  \
# 0             0       F                       ROBBERY  2019-12-31        U
# 1             1       F                 PETIT LARCENY  2019-12-30      NaN
# 2             2       M                FELONY ASSAULT  2019-12-24        M
# 3             3       D                 PETIT LARCENY  2019-12-30        F
# 4             4       M                 PETIT LARCENY  2019-12-30      NaN
# ..          ...     ...                           ...         ...      ...
# 995         995       M  ASSAULT 3 & RELATED OFFENSES  2019-08-25      NaN
# 996         996       M                 PETIT LARCENY  2019-04-19      NaN
# 997         997       M                 PETIT LARCENY  2019-08-30      NaN
# 998         998       F                 PETIT LARCENY  2019-04-20        U
# 999         999       M  ASSAULT 3 & RELATED OFFENSES  2019-04-20        U
#
# ...

# %%
parks_properties_df = pd.read_csv('cleaned_data/parks_properties.csv')
parks_properties_df
# Out:
#      Unnamed: 0   latitude  longitude                     category  \
# 0             0  40.756623 -73.727964  Jointly Operated Playground
# 1             1  40.674433 -73.865252            Neighborhood Park
# 2             2  40.525576 -74.184467                  Nature Area
# 3             3  40.876281 -73.891882            Neighborhood Park
# 4             4  40.842200 -73.888758                        Strip
# ..          ...        ...        ...                          ...
# 995         995  40.862030 -73.890417               Triangle/Plaza
# 996         996  40.627848 -74.073075          Waterfront Facility
# 997         997  40.684662 -73.922883                       Garden
# 998         998  40.809486 -73.917005                   Playground
# 999         999  40.805242 -73.924566      Recreation Field/Courts
#
#                                        name  waterfront   acres  \
# 0                      Challenge Playground       False   2.035
# ...

# %%
school_locations_df = pd.read_csv('cleaned_data/school_locations.csv')
school_locations_df
# Out:
#      Unnamed: 0   latitude  longitude                         category  \
# 0             0  40.648959 -74.011420                       Elementary
# 1             1  40.656423 -73.951575  Junior High-Intermediate-Middle
# 2             2  40.682311 -73.955219                       Elementary
# 3             3  40.658500 -73.879276                       Elementary
# 4             4  40.685241 -73.921970                       Elementary
# ..          ...        ...        ...                              ...
# 995         995  40.704697 -74.011202                      High school
# 996         996  40.743407 -74.002540                      High school
# 997         997  40.732665 -73.982590                      High school
# 998         998  40.799098 -73.965611  Junior High-Intermediate-Middle
# 999         999  40.743407 -74.002540                 Secondary School
#
#                                                   name  \
# 0                                  P.S. 001 The Bergen
# ...

# %%
subway_stations_df = pd.read_csv('cleaned_data/subway_stations.csv')
subway_stations_df
# Out:
#      Unnamed: 0                         name           line  longitude  \
# 0             0                     Astor Pl  4-6-6 Express -73.991070
# 1             1                     Canal St  4-6-6 Express -74.000193
# 2             2                      50th St            1-2 -73.983849
# 3             3                    Bergen St          2-3-4 -73.974999
# 4             4             Pennsylvania Ave            3-4 -73.894886
# ..          ...                          ...            ...        ...
# 468         468  Coney Island - Stillwell Av        D-F-N-Q -73.981236
# 469         469       34th St - Hudson Yards    7-7 Express -74.002197
# 470         470                      72nd St              Q -73.958362
# 471         471                      86th St              Q -73.951771
# 472         472                      96th St              Q -73.947066
#
#       latitude      neighborhood    borough          area
# ...
