# %%
import pandas as pd
import numpy as np

# %%
nypd_complains_df = pd.read_parquet('cleaned_data/nypd_complaints.parquet')
nypd_complains_df
# Out:
#        vic_sex                       offense       date susp_sex     category  \
# 0            F                       ROBBERY 2019-12-31        U       FELONY
# 1            F                 PETIT LARCENY 2019-12-30     None  MISDEMEANOR
# 2            M                FELONY ASSAULT 2019-12-24        M       FELONY
# 3            D                 PETIT LARCENY 2019-12-30        F  MISDEMEANOR
# 4            M                 PETIT LARCENY 2019-12-30     None  MISDEMEANOR
# ...        ...                           ...        ...      ...          ...
# 461706       M      VEHICLE AND TRAFFIC LAWS 2019-01-03     None  MISDEMEANOR
# 461707       M                FELONY ASSAULT 2019-01-02        F       FELONY
# 461708       D                 PETIT LARCENY 2019-01-05        F  MISDEMEANOR
# 461709       M  ASSAULT 3 & RELATED OFFENSES 2019-01-04     None  MISDEMEANOR
# 461710       E               DANGEROUS DRUGS 2018-01-02        M  MISDEMEANOR
#
# ...

# %%
parks_properties_df = pd.read_parquet('cleaned_data/parks_properties.parquet')
parks_properties_df
# Out:
#        latitude  longitude                     category  \
# 0     40.756623 -73.727964  Jointly Operated Playground
# 1     40.674433 -73.865252            Neighborhood Park
# 2     40.525576 -74.184467                  Nature Area
# 3     40.876281 -73.891882            Neighborhood Park
# 4     40.842200 -73.888758                        Strip
# ...         ...        ...                          ...
# 2012  40.813785 -73.830495                Flagship Park
# 2013  40.813069 -73.962079            Neighborhood Park
# 2014  40.701160 -73.987588                      Parkway
# 2015  40.701933 -73.933035            Neighborhood Park
# 2016  40.661466 -73.744182               Community Park
#
#                         name  waterfront   acres         neighborhood  \
# 0       Challenge Playground       False   2.035          Little Neck
# 1     Robert E. Venable Park       False   2.939        East New York
# 2          Kingdom Pond Park       False    4.22             Huguenot
# ...

# %%
school_locations_df = pd.read_parquet('cleaned_data/school_locations.parquet')
school_locations_df
# Out:
#        latitude  longitude                         category  \
# 0     40.648959 -74.011420                       Elementary
# 1     40.656423 -73.951575  Junior High-Intermediate-Middle
# 2     40.682311 -73.955219                       Elementary
# 3     40.658500 -73.879276                       Elementary
# 4     40.685241 -73.921970                       Elementary
# ...         ...        ...                              ...
# 2185  40.814900 -73.917000                       Elementary
# 2186  40.821815 -73.886477                       Elementary
# 2187  40.811051 -73.909363                      High school
# 2188  40.830552 -73.886798                 Secondary School
# 2189  40.830552 -73.886798                 Secondary School
#
#                                          name               neighborhood  \
# 0                         P.S. 001 The Bergen                Sunset Park
# 1                Parkside Preparatory Academy  Prospect Lefferts Gardens
# ...

# %%
subway_stations_df = pd.read_parquet('cleaned_data/subway_stations.parquet')
subway_stations_df
# Out:
#                             name           line  longitude   latitude  \
# 0                       Astor Pl  4-6-6 Express -73.991070  40.730054
# 1                       Canal St  4-6-6 Express -74.000193  40.718803
# 2                        50th St            1-2 -73.983849  40.761728
# 3                      Bergen St          2-3-4 -73.974999  40.680862
# 4               Pennsylvania Ave            3-4 -73.894886  40.664714
# ..                           ...            ...        ...        ...
# 468  Coney Island - Stillwell Av        D-F-N-Q -73.981236  40.577281
# 469       34th St - Hudson Yards    7-7 Express -74.002197  40.755446
# 470                      72nd St              Q -73.958362  40.768803
# 471                      86th St              Q -73.951771  40.777861
# 472                      96th St              Q -73.947066  40.784237
#
#          neighborhood    borough          area
# 0        East Village  Manhattan  1.847620e+06
# ...
